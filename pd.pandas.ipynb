# %%
# !pip install pandas

# %%
import pandas as pd 
series1= pd.Series([10,20,30])
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
series2 = pd.Series(["goldan","mohsin","imran"], index=[1,2,3])
print(series2)
# Out:
# 1    goldan
# 2    mohsin
# 3     imran
# dtype: object

# %%
import numpy as np
import pandas as pd 
array1 = np.array([1,2,3,4])
series2 = pd.Series(array1)
print(series2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
series4= pd.Series(array1, index = ["jan", "fab", "mar", "apr"])
print(series4)
# Out:
# jan    1
# fab    2
# mar    3
# apr    4
# dtype: int32

# %%
dict1 = {'india': 'newdelhi','uk':'london','japan': 'tokyo'}
print(dict1)
{'india': 'newdelhi','uk':'london', 'japan': 'tokyo'}
# Out:
# {'india': 'newdelhi', 'uk': 'london', 'japan': 'tokyo'}
# {'india': 'newdelhi', 'uk': 'london', 'japan': 'tokyo'}

# %%
series8= pd.Series(dict1)
print(series8)
# Out:
# india    newdelhi
# uk         london
# japan       tokyo
# dtype: object

# %%
seriesmnths = pd.Series([1,2,3],index=["jan","mar","apr"])
seriesmnths["mar"]
# Out:
# 2

# %%
seriescapcntry = pd.Series(['newdelhi', 'washingtondc', 'london', 'paris'], index=['india', 'usa', 'uk', 'france'])
seriescapcntry
# Out:
# india         newdelhi
# usa       washingtondc
# uk              london
# france           paris
# dtype: object

# %%
import numpy as np
import pandas as pd 
seriestentwenty=pd.Series(np.arange(10,20, 1 ))
print(seriestentwenty)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int32

# %%
seriestentwenty.head(2)
# Out:
# 0    10
# 1    11
# dtype: int32

# %%
seriestentwenty.count()
# Out:
# 10

# %%
seriestentwenty.tail(2)
# Out:
# 8    18
# 9    19
# dtype: int32

# %%
seriesA = pd.Series([1,2,3,4,5,6], index=['a','b','c','d','e','c'])
seriesA
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# c    6
# dtype: int64

# %%
seriesB = pd.Series([10,20,30,40,50,7],
                    index = ['a','b','c','d','e','c'])
seriesB
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# c     7
# dtype: int64

# %%
seriesA + seriesB
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# c    13
# dtype: int64

# %%
seriesA - seriesB
# Out:
# a    -9
# b   -18
# c   -27
# d   -36
# e   -45
# c    -1
# dtype: int64

# %%
seriesA * seriesB
# Out:
# a     10
# b     40
# c     90
# d    160
# e    250
# c     42
# dtype: int64

# %%
import numpy as np
array1 = np.array([10,20,30])
array2 = np.array([100,200,300])
array3 = np.array([-10,-20,-40,-50])
gframe4 = pd.DataFrame(array3)
gframe4
# Out:
#     0
# 0 -10
# 1 -20
# 2 -40
# 3 -50

# %%
listDict = [{'a':10, 'b':20}, {'a':5, 'b':10, 'c':20}]
dframelistdict = pd.DataFrame(listDict)
dframelistdict
# Out:
#     a   b     c
# 0  10  20   NaN
# 1   5  10  20.0

# %%
import pandas as pd
resultsheet={'goldan': pd.Series([90,91,97,.50],index=['maths','science','hindi','english']),
             'divyansh':pd.Series([92,81,96,50],index=['maths','science','hindi','english']),
             'parkhar':pd.Series ([89,91,88,50],index=['maths','science','hindi','english']),
             'puja':pd.Series ([81,71,67,50],index=['maths','science','hindi','english']),
             'mansi':pd.Series ([94,95,99,50],index=['maths','science','hindi','english']),
             'mohsin':pd.Series ([100,100,100,50],index=['maths','science','hindi','english']),
             'imran':pd.Series ([100,100,100,50],index=['maths','science','hindi','english']),
              'yasin':pd.Series ([100,100,100,50],index=['maths','science','hindi','english'])}

resultDF = pd.DataFrame(resultsheet)
resultDF
# Out:
#          goldan  divyansh  parkhar  puja  mansi  mohsin  imran  yasin
# maths      90.0        92       89    81     94     100    100    100
# science    91.0        81       91    71     95     100    100    100
# hindi      97.0        96       88    67     99     100    100    100
# english     0.5        50       50    50     50      50     50     50

# %%
resultDF['jimmy']=[89,78,76,86]
resultDF
# Out:
#          goldan  divyansh  parkhar  puja  mansi  mohsin  imran  yasin  jimmy
# maths      90.0        92       89    81     94     100    100    100     89
# science    91.0        81       91    71     95     100    100    100     78
# hindi      97.0        96       88    67     99     100    100    100     76
# english     0.5        50       50    50     50      50     50     50     86

# %%
resultDF.loc['bio'] = [84,73,78,98,98,78,23,45,89]
resultDF
# Out:
#          goldan  divyansh  parkhar  puja  mansi  mohsin  imran  yasin  jimmy
# maths      90.0        92       89    81     94     100    100    100     89
# science    91.0        81       91    71     95     100    100    100     78
# hindi      97.0        96       88    67     99     100    100    100     76
# english     0.5        50       50    50     50      50     50     50     86
# bio        84.0        73       78    98     98      78     23     45     89

# %%
resultDF = resultDF.drop('science',axis=0)
resultDF
# Out:
#          goldan  divyansh  parkhar  puja  mansi  mohsin  imran  yasin  jimmy
# maths      90.0        92       89    81     94     100    100    100     89
# hindi      97.0        96       88    67     99     100    100    100     76
# english     0.5        50       50    50     50      50     50     50     86
# bio        84.0        73       78    98     98      78     23     45     89

# %%
resultDF = resultDF.drop(['puja','mansi'],axis=1)
resultDF
# Out:
#          goldan  divyansh  parkhar  mohsin  imran  yasin  jimmy
# maths      90.0        92       89     100    100    100     89
# hindi      97.0        96       88     100    100    100     76
# english     0.5        50       50      50     50     50     86
# bio        84.0        73       78      78     23     45     89

# %%
resultDF=resultDF.rename({'maths':'sub1','english':'sub2','hindi':'sub3','bio':'sub4'},axis='index')
resultDF
# Out:
#       goldan  divyansh  parkhar  mohsin  imran  yasin  jimmy
# sub1    90.0        92       89     100    100    100     89
# sub3    97.0        96       88     100    100    100     76
# sub2     0.5        50       50      50     50     50     86
# sub4    84.0        73       78      78     23     45     89

# %%
resultDF.loc['sub3']
# Out:
# goldan       97.0
# divyansh     96.0
# parkhar      88.0
# mohsin      100.0
# imran       100.0
# yasin       100.0
# jimmy        76.0
# Name: sub3, dtype: float64

# %%
resultDF.loc['sub1': 'sub2']
# Out:
#       goldan  divyansh  parkhar  mohsin  imran  yasin  jimmy
# sub1    90.0        92       89     100    100    100     89
# sub3    97.0        96       88     100    100    100     76
# sub2     0.5        50       50      50     50     50     86

# %%
import pandas as pd
resultsheet={'goldan': pd.Series([90,91,97,50,50,90,47],index=['maths','science','hindi','english','comp','excel','python']),
             'divyansh':pd.Series([92,81,96,50,90,80,60],index=['maths','science','hindi','english','comp','excel','python']),
             'parkhar':pd.Series ([89,91,88,50,70,60,76],index=['maths','science','hindi','english','comp','excel','python']),
             'puja':pd.Series ([81,71,67,50,60,40,70],index=['maths','science','hindi','english','comp','excel','python']),
             'mansi':pd.Series ([94,95,99,50,50,90,70],index=['maths','science','hindi','english','comp','excel','python']),
             'mohsin':pd.Series ([100,100,100,50,70,80,80],index=['maths','science','hindi','english','comp','excel','python']),
             'imran':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
              'yasin':pd.Series ([100,100,100,50,40,60,80],index=['maths','science','hindi','english','comp','excel','python']),
             'arman':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'tarik':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'danis':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'wasim':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'taha':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'farid':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'micky':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python']),
             'cho2':pd.Series ([100,100,100,50,60,40,80],index=['maths','science','hindi','english','comp','excel','python'])}

resultDF = pd.DataFrame(resultsheet)
resultDF
# Out:
#          goldan  divyansh  parkhar  puja  mansi  mohsin  imran  yasin  arman  \
# maths        90        92       89    81     94     100    100    100    100
# science      91        81       91    71     95     100    100    100    100
# hindi        97        96       88    67     99     100    100    100    100
# english      50        50       50    50     50      50     50     50     50
# comp         50        90       70    60     50      70     60     40     60
# excel        90        80       60    40     90      80     40     60     40
# python       47        60       76    70     70      80     80     80     80
#
#          tarik  danis  wasim  taha  farid  micky  cho2
# maths      100    100    100   100    100    100   100
# science    100    100    100   100    100    100   100
# hindi      100    100    100   100    100    100   100
# english     50     50     50    50     50     50    50
# comp        60     60     60    60     60     60    60
# ...

# %%
import pandas as pd
df3=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Mall_Customers.csv")
df3
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Copy of Netflix_Sales_Data_With_Genre(1).csv")
df
# Out:
#            Date         Region Subscription Type    Show Type     Genre  \
# 0    2024-01-01  North America             Basic        Movie   Romance
# 1    2024-01-01  North America          Standard  Documentary    Horror
# 2    2024-01-01  North America           Premium  Documentary  Thriller
# 3    2024-01-01  North America            Mobile        Movie    Comedy
# 4    2024-01-01         Europe             Basic        Movie    Action
# ..          ...            ...               ...          ...       ...
# 475  2025-12-01  South America            Mobile       Series  Thriller
# 476  2025-12-01         Africa             Basic        Movie  Thriller
# 477  2025-12-01         Africa          Standard  Documentary    Action
# 478  2025-12-01         Africa           Premium       Series    Action
# 479  2025-12-01         Africa            Mobile        Movie    Sci-Fi
#
#      New Subscribers  Monthly Price     Revenue  Content Cost  Marketing Cost  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Region', 'Subscription Type', 'Show Type', 'Genre',
#        'New Subscribers', 'Monthly Price', 'Revenue', 'Content Cost',
#        'Marketing Cost', 'Operating Cost', 'Total Cost', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               480 non-null    object
#  1   Region             480 non-null    object
#  2   Subscription Type  480 non-null    object
#  3   Show Type          480 non-null    object
#  4   Genre              480 non-null    object
#  5   New Subscribers    480 non-null    int64
#  6   Monthly Price      480 non-null    float64
#  7   Revenue            480 non-null    float64
#  8   Content Cost       480 non-null    float64
#  9   Marketing Cost     480 non-null    float64
#  10  Operating Cost     480 non-null    float64
#  11  Total Cost         480 non-null    float64
#  12  Profit             480 non-null    float64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 48.9+ KB

# %%
df.describe()
# Out:
#        New Subscribers  Monthly Price       Revenue  Content Cost  \
# count       480.000000     480.000000  4.800000e+02  4.800000e+02
# mean      80148.164583      13.240000  1.051090e+06  4.170321e+05
# std       41068.156480       5.073571  7.003698e+05  2.776236e+05
# min       10124.000000       6.990000  7.076676e+04  2.786391e+04
# 25%       40781.750000       9.240000  5.230370e+05  2.078107e+05
# 50%       80161.000000      12.990000  8.601771e+05  3.408062e+05
# 75%      115317.750000      16.990000  1.442444e+06  5.675727e+05
# max      149674.000000      19.990000  2.978890e+06  1.327122e+06
#
#        Marketing Cost  Operating Cost    Total Cost        Profit
# count      480.000000      480.000000  4.800000e+02  4.800000e+02
# mean    157243.389042   157240.425438  7.315159e+05  3.195743e+05
# std     108543.347604   109165.320846  4.841390e+05  2.277799e+05
# min       8072.760000     9217.700000  4.962788e+04  2.030338e+04
# ...

# %%
df.head()
# Out:
#          Date         Region Subscription Type    Show Type     Genre  \
# 0  2024-01-01  North America             Basic        Movie   Romance
# 1  2024-01-01  North America          Standard  Documentary    Horror
# 2  2024-01-01  North America           Premium  Documentary  Thriller
# 3  2024-01-01  North America            Mobile        Movie    Comedy
# 4  2024-01-01         Europe             Basic        Movie    Action
#
#    New Subscribers  Monthly Price     Revenue  Content Cost  Marketing Cost  \
# 0            65642           9.99   655763.58     267213.35        77475.37
# 1            35727          15.99   571274.73     217923.07        72083.32
# 2            46066          19.99   920859.34     370130.26       156228.18
# 3            94330           6.99   659366.70     237824.28       117221.07
# 4           126554           9.99  1264274.46     564028.32       211490.80
#
#    Operating Cost  Total Cost     Profit
# 0        66878.62   411567.34  244196.24
# ...

# %%
df.tail()
# Out:
#            Date         Region Subscription Type    Show Type     Genre  \
# 475  2025-12-01  South America            Mobile       Series  Thriller
# 476  2025-12-01         Africa             Basic        Movie  Thriller
# 477  2025-12-01         Africa          Standard  Documentary    Action
# 478  2025-12-01         Africa           Premium       Series    Action
# 479  2025-12-01         Africa            Mobile        Movie    Sci-Fi
#
#      New Subscribers  Monthly Price     Revenue  Content Cost  Marketing Cost  \
# 475            49668           6.99   347179.32     130424.78        54320.88
# 476            50887           9.99   508361.13     227329.56        70763.59
# 477           114819          15.99  1835955.81     653458.09       324991.89
# 478            74344          19.99  1486136.56     594537.85       216166.50
# 479            52599           6.99   367667.01     150572.00        47064.78
#
#      Operating Cost  Total Cost     Profit
# ...

# %%
df.shape
# Out:
# (480, 13)

# %%
import pandas as pd 
df1=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\Desktop\\Sample - Superstore.csv",encoding='latin-1')
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df1.head
# Out:
# <bound method NDFrame.head of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df1['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df1['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
(df1["Sub-Category"].value_counts()).sort_values(ascending=False)
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df1.sort_values(["Category","Profit"])
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9639    9640  CA-2015-116638   1/28/2015   1/31/2015    Second Class
# 27        28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# 5320    5321  US-2017-162558   10/2/2017   10/5/2017     First Class
# 8993    8994  CA-2017-159100  10/16/2017  10/21/2017  Standard Class
# 463      464  CA-2016-109869   4/22/2016   4/29/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 8488    8489  CA-2016-158841    2/2/2016    2/4/2016    Second Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
df1.drop_duplicates(subset=["Sub-Category"])
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5         6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6         7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7         8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8         9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9        10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 12       13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# 26       27  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 30       31  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# ...

# %%
df1.drop_duplicates(subset=["Sub-Category"]).shape
# Out:
# (17, 21)

# %%
df1.shape
# Out:
# (9994, 21)

# %%
hello = df1.groupby("Category")
hello

# %%
len(df1)
# Out:
# 9994

# %%
len("Catego")
# Out:
# 6

# %%
hello.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
import pandas as pd 
df11=pd.read_csv('data helth.csv')
df11
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df11.rename(columns={'Duration':'timing'})
# Out:
#      timing  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# ..      ...    ...       ...       ...
# 164      60    105       140     290.8
# 165      60    110       145     300.0
# 166      60    115       145     310.2
# 167      75    120       150     320.4
# 168      75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df11.rename(index={0:'firstentry', 1:'secondentry'})
# Out:
#              Duration  Pulse  Maxpulse  Calories
# firstentry         60    110       130     409.1
# secondentry        60    117       145     479.0
# 2                  60    103       135     340.0
# 3                  45    109       175     282.4
# 4                  45    117       148     406.0
# ...               ...    ...       ...       ...
# 164                60    105       140     290.8
# 165                60    110       145     300.0
# 166                60    115       145     310.2
# 167                75    120       150     320.4
# 168                75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.concat([df11, df1])
# Out:
#       Duration  Pulse  Maxpulse  Calories  Row ID        Order ID Order Date  \
# 0         60.0  110.0     130.0     409.1     NaN             NaN        NaN
# 1         60.0  117.0     145.0     479.0     NaN             NaN        NaN
# 2         60.0  103.0     135.0     340.0     NaN             NaN        NaN
# 3         45.0  109.0     175.0     282.4     NaN             NaN        NaN
# 4         45.0  117.0     148.0     406.0     NaN             NaN        NaN
# ...        ...    ...       ...       ...     ...             ...        ...
# 9989       NaN    NaN       NaN       NaN  9990.0  CA-2014-110422  1/21/2014
# 9990       NaN    NaN       NaN       NaN  9991.0  CA-2017-121258  2/26/2017
# 9991       NaN    NaN       NaN       NaN  9992.0  CA-2017-121258  2/26/2017
# 9992       NaN    NaN       NaN       NaN  9993.0  CA-2017-121258  2/26/2017
# 9993       NaN    NaN       NaN       NaN  9994.0  CA-2017-119914   5/4/2017
#
# ...
